# %% [markdown]
# ### Data Legend
#
# #### Application Data
# | Row                           | Description                                                                                   | Special |
# |-------------------------------|-----------------------------------------------------------------------------------------------|---------|
# | SK_ID_CURR                    | ID of loan in our sample                                                                      |         |
# | TARGET                        | Target variable (1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 0 - all other cases) |         |
# | NAME_CONTRACT_TYPE            | Identification if the loan is cash or revolving                                              |         |
# | CODE_GENDER                   | Gender of the client                                                                         |         |
# | FLAG_OWN_CAR                  | Flag if the client owns a car                                                                |         |
# | FLAG_OWN_REALTY               | Flag if the client owns a house or flat                                                      |         |
# | CNT_CHILDREN                  | Number of children the client has                                                            |         |
# | AMT_INCOME_TOTAL              | Income of the client                                                                         |         |
# | AMT_CREDIT                    | Credit amount of the loan                                                                    |         |
# | AMT_ANNUITY                   | Loan annuity                                                                                 |         |
# | AMT_GOODS_PRICE               | For consumer loans, it is the price of the goods for which the loan is given               |         |
# | NAME_TYPE_SUITE               | Who was accompanying the client when applying for the loan                                   |         |
# | NAME_INCOME_TYPE              | Clients' income type (businessman, working, maternity leave, ...)                             |         |
# | NAME_EDUCATION_TYPE           | Level of the highest education the client achieved                                           |         |
# | NAME_FAMILY_STATUS            | Family status of the client                                                                 |         |
# | NAME_HOUSING_TYPE             | What is the housing situation of the client (renting, living with parents, ...)               |         |
# | REGION_POPULATION_RELATIVE    | Normalized population of the region where the client lives (higher number means the client lives in a more populated region) | Normalized |
# | DAYS_BIRTH                    | Client's age in days at the time of application                                                | Time only relative to the application |
# | DAYS_EMPLOYED                 | How many days before the application the person started current employment                   | Time only relative to the application |
# | DAYS_REGISTRATION             | How many days before the application did the client change his registration                   | Time only relative to the application |
# | DAYS_ID_PUBLISH               | How many days before the application did the client change the identity document with which he applied for the loan | Time only relative to the application |
# | OWN_CAR_AGE                   | Age of the client's car                                                                      |         |
# | FLAG_MOBIL                    | Did the client provide a mobile phone (1=YES, 0=NO)                                           |         |
# | FLAG_EMP_PHONE                | Did the client provide a work phone (1=YES, 0=NO)                                             |         |
# | FLAG_WORK_PHONE               | Did the client provide a home phone (1=YES, 0=NO)                                            |         |
# | FLAG_CONT_MOBILE              | Was the mobile phone reachable (1=YES, 0=NO)                                                |         |
# | FLAG_PHONE                    | Did the client provide a home phone (1=YES, 0=NO)                                            |         |
# | FLAG_EMAIL                    | Did the client provide an email (1=YES, 0=NO)                                               |         |
# | OCCUPATION_TYPE               | What kind of occupation does the client have                                                |         |
# | CNT_FAM_MEMBERS               | How many family members does the client have                                                 |         |
# | REGION_RATING_CLIENT          | Our rating of the region where the client lives (1,2,3)                                     |         |
# | REGION_RATING_CLIENT_W_CITY   | Our rating of the region where the client lives with taking the city into account (1,2,3) |         |
# | WEEKDAY_APPR_PROCESS_START    | On which day of the week did the client apply for the loan                                   |         |
# | HOUR_APPR_PROCESS_START       | Approximately at what hour did the client apply for the loan                                 | Rounded |
# | REG_REGION_NOT_LIVE_REGION    | Flag if the client's permanent address does not match the contact address (1=different, 0=same, at region level) |         |
# | REG_REGION_NOT_WORK_REGION    | Flag if the client's permanent address does not match the work address (1=different, 0=same, at region level) |         |
# | LIVE_REGION_NOT_WORK_REGION   | Flag if the client's contact address does not match the work address (1=different, 0=same, at region level) |         |
# | REG_CITY_NOT_LIVE_CITY        | Flag if the client's permanent address does not match the contact address (1=different, 0=same, at city level) |         |
# | REG_CITY_NOT_WORK_CITY        | Flag if the client's permanent address does not match the work address (1=different, 0=same, at city level) |         |
# | LIVE_CITY_NOT_WORK_CITY       | Flag if the client's contact address does not match the work address (1=different, 0=same, at city level) |         |
# | ORGANIZATION_TYPE             | Type of organization where the client works                                                   |         |
# | EXT_SOURCE_1                  | Normalized score from an external data source                                                 | Normalized |
# | EXT_SOURCE_2                  | Normalized score from an external data source                                                 | Normalized |
# | EXT_SOURCE_3                  | Normalized score from an external data source                                                 | Normalized |
# | APARTMENTS_AVG                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | BASEMENTAREA_AVG              | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BEGINEXPLUATATION_AVG   | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BUILD_AVG               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | COMMONAREA_AVG                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ELEVATORS_AVG                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ENTRANCES_AVG                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMAX_AVG                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMIN_AVG                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LANDAREA_AVG                  | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAPARTMENTS_AVG          | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAREA_AVG                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAPARTMENTS_AVG       | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAREA_AVG             | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | APARTMENTS_MODE               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | BASEMENTAREA_MODE             | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BEGINEXPLUATATION_MODE  | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BUILD_MODE              | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | COMMONAREA_MODE               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ELEVATORS_MODE                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ENTRANCES_MODE                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMAX_MODE                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMIN_MODE                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LANDAREA_MODE                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAPARTMENTS_MODE         | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAREA_MODE               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAPARTMENTS_MODE      | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAREA_MODE            | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | APARTMENTS_MEDI               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | BASEMENTAREA_MEDI             | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BEGINEXPLUATATION_MEDI  | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | YEARS_BUILD_MEDI              | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | COMMONAREA_MEDI               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ELEVATORS_MEDI                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | ENTRANCES_MEDI                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMAX_MEDI                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FLOORSMIN_MEDI                | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LANDAREA_MEDI                 | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAPARTMENTS_MEDI         | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | LIVINGAREA_MEDI               | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAPARTMENTS_MEDI      | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | NONLIVINGAREA_MEDI            | Normalized information about the building where the client lives (average size, mode, median) | Normalized |
# | FONDKAPREMONT_MODE            | Normalized information about building size, common area, living area, age of building, elevators, entrances, state of the building, number of floors | Normalized |
# | HOUSETYPE_MODE                | Normalized information about building size, common area, living area, age of building, elevators, entrances, state of the building, number of floors | Normalized |
# | TOTALAREA_MODE                | Normalized information about building size, common area, living area, age of building, elevators, entrances, state of the building, number of floors | Normalized |
# | WALLSMATERIAL_MODE            | Normalized information about building size, common area, living area, age of building, elevators, entrances, state of the building, number of floors | Normalized |
# | EMERGENCYSTATE_MODE           | Normalized information about building size, common area, living area, age of building, elevators, entrances, state of the building, number of floors | Normalized |
# | OBS_30_CNT_SOCIAL_CIRCLE      | How many observations of the client's social surroundings with observable 30 DPD (days past due) default |         |
# | DEF_30_CNT_SOCIAL_CIRCLE      | How many observations of the client's social surroundings defaulted on 30 DPD (days past due) |         |
# | OBS_60_CNT_SOCIAL_CIRCLE      | How many observations of the client's social surroundings with observable 60 DPD (days past due) default |         |
# | DEF_60_CNT_SOCIAL_CIRCLE      | How many observations of the client's social surroundings defaulted on 60 DPD (days past due) |         |
# | DAYS_LAST_PHONE_CHANGE        | How many days before application did the client change phone                                  |         |
# | FLAG_DOCUMENT_2               | Did the client provide document 2                                                             |         |
# | FLAG_DOCUMENT_3               | Did the client provide document 3                                                             |         |
# | FLAG_DOCUMENT_4               | Did the client provide document 4                                                             |         |
# | FLAG_DOCUMENT_5               | Did the client provide document 5                                                             |         |
# | FLAG_DOCUMENT_6               | Did the client provide document 6                                                             |         |
# | FLAG_DOCUMENT_7               | Did the client provide document 7                                                             |         |
# | FLAG_DOCUMENT_8               | Did the client provide document 8                                                             |         |
# | FLAG_DOCUMENT_9               | Did the client provide document 9                                                             |         |
# | FLAG_DOCUMENT_10              | Did the client provide document 10                                                            |         |
# | FLAG_DOCUMENT_11              | Did the client provide document 11                                                            |         |
# | FLAG_DOCUMENT_12              | Did the client provide document 12                                                            |         |
# | FLAG_DOCUMENT_13              | Did the client provide document 13                                                            |         |
# | FLAG_DOCUMENT_14              | Did the client provide document 14                                                            |         |
# | FLAG_DOCUMENT_15              | Did the client provide document 15                                                            |         |
# | FLAG_DOCUMENT_16              | Did the client provide document 16                                                            |         |
# | FLAG_DOCUMENT_17              | Did the client provide document 17                                                            |         |
# | FLAG_DOCUMENT_18              | Did the client provide document 18                                                            |         |
# | FLAG_DOCUMENT_19              | Did the client provide document 19                                                            |         |
# | FLAG_DOCUMENT_20              | Did the client provide document 20                                                            |         |
# | FLAG_DOCUMENT_21              | Did the client provide document 21                                                            |         |
# | AMT_REQ_CREDIT_BUREAU_HOUR    | Number of inquiries to Credit Bureau about the client one hour before application            |         |
# | AMT_REQ_CREDIT_BUREAU_DAY     | Number of inquiries to Credit Bureau about the client one day before application (excluding one hour before application) |         |
# | AMT_REQ_CREDIT_BUREAU_WEEK    | Number of inquiries to Credit Bureau about the client one week before application (excluding one day before application) |         |
# | AMT_REQ_CREDIT_BUREAU_MON     | Number of inquiries to Credit Bureau about the client one month before application (excluding one week before application) |         |
# | AMT_REQ_CREDIT_BUREAU_QRT     | Number of inquiries to Credit Bureau about the client 3 months before application (excluding one month before application) |         |
# | AMT_REQ_CREDIT_BUREAU_YEAR    | Number of inquiries to Credit Bureau about the client one day year (excluding the last 3 months before application) |         |
#
# #### Bureau Data
# | Row                  | Description                                                                                     |
# |----------------------|-------------------------------------------------------------------------------------------------|
# | SK_ID_CURR           | ID of loan in our sample - one loan in our sample can have 0,1,2 or more related previous credits in credit bureau |
# | SK_BUREAU_ID         | Recoded ID of previous Credit Bureau credit related to our loan (unique coding for each loan application) |
# | CREDIT_ACTIVE        | Status of the Credit Bureau (CB) reported credits |
# | CREDIT_CURRENCY      | Recoded currency of the Credit Bureau credit |
# | DAYS_CREDIT          | How many days before the current application did the client apply for Credit Bureau credit |
# | CREDIT_DAY_OVERDUE   | Number of days past due on CB credit at the time of application for related loan in our sample |
# | DAYS_CREDIT_ENDDATE  | Remaining duration of CB credit (in days) at the time of application in Home Credit |
# | DAYS_ENDDATE_FACT    | Days since CB credit ended at the time of application in Home Credit (only for closed credit) |
# | AMT_CREDIT_MAX_OVERDUE | Maximal amount overdue on the Credit Bureau credit so far (at the application date of the loan in our sample) |
# | CNT_CREDIT_PROLONG  | How many times was the Credit Bureau credit prolonged |
# | AMT_CREDIT_SUM       | Current credit amount for the Credit Bureau credit |
# | AMT_CREDIT_SUM_DEBT  | Current debt on Credit Bureau credit |
# | AMT_CREDIT_SUM_LIMIT | Current credit limit of the credit card reported in Credit Bureau |
# | AMT_CREDIT_SUM_OVERDUE | Current amount overdue on Credit Bureau credit |
# | CREDIT_TYPE          | Type of Credit Bureau credit (Car, cash,...) |
# | DAYS_CREDIT_UPDATE   | How many days before the loan application did the last information about the Credit Bureau credit come |
# | AMT_ANNUITY          | Annuity of the Credit Bureau credit |
# | SK_BUREAU_ID         | Recoded ID of Credit Bureau credit (unique coding for each application) - use this to join to CREDIT_BUREAU table |
# | MONTHS_BALANCE       | Month of balance relative to the application date (-1 means the freshest balance date) |
# | STATUS              | Status of Credit Bureau loan during the month (active, closed, DPD0-30, [C means closed, X means status unknown, 0 means no DPD, 1 means maximal did during the month between 1-30, 2 means DPD 31-60, 5 means DPD 120+ or sold or written off) |
